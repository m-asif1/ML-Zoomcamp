# %% [markdown]
# ## 2. Machine Learning for Regression

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## 2.2 Data preparation

# %%
data = 'https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv'

# %%
# !wget $data
# Out:
# --2024-10-06 13:32:51--  https://raw.githubusercontent.com/alexeygrigorev/mlbookcamp-code/master/chapter-02-car-price/data.csv
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.111.133, 185.199.108.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1475504 (1.4M) [text/plain]
# Saving to: 'data.csv'
#
#      0K .......... .......... .......... .......... ..........  3% 83.5K 17s
#     50K .......... .......... .......... .......... ..........  6% 78.6K 17s
#    100K .......... .......... .......... .......... .......... 10%  100K 15s
#    150K .......... .......... .......... .......... .......... 13%  194K 12s
#    200K .......... .......... .......... .......... .......... 17%  233K 11s
#    250K .......... .......... .......... .......... .......... 20%  212K 9s
# ...

# %%
df = pd.read_csv('data.csv')

# %%
df.head()
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
df['Transmission Type']
# Out:
# 0           MANUAL
# 1           MANUAL
# 2           MANUAL
# 3           MANUAL
# 4           MANUAL
#            ...
# 11909    AUTOMATIC
# 11910    AUTOMATIC
# 11911    AUTOMATIC
# 11912    AUTOMATIC
# 11913    AUTOMATIC
# Name: Transmission Type, Length: 11914, dtype: object

# %%
# index is special data structure in pandas similar to series
df.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
# doing string manipulations all the column names to lower case with 
# multiple string commands replace spaces with underscores
df.columns = df.columns.str.lower().str.replace(' ', '_')
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
df['make'].str.lower().str.replace(' ', '_')
# Out:
# 0            bmw
# 1            bmw
# 2            bmw
# 3            bmw
# 4            bmw
#           ...
# 11909      acura
# 11910      acura
# 11911      acura
# 11912      acura
# 11913    lincoln
# Name: make, Length: 11914, dtype: object

# %%
# look at head top first records we see that everything is more uniform lowercase
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
# find all the string columns and type of column
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %%
# check what is object and what is not
df.dtypes == 'object'
# Out:
# make                  True
# model                 True
# year                 False
# engine_fuel_type      True
# engine_hp            False
# engine_cylinders     False
# transmission_type     True
# driven_wheels         True
# number_of_doors      False
# market_category       True
# vehicle_size          True
# vehicle_style         True
# highway_mpg          False
# city_mpg             False
# popularity           False
# msrp                 False
# dtype: bool

# %%
# select only those that are objects
# left side names is index and right side object is values
df.dtypes[df.dtypes == 'object']
# Out:
# make                 object
# model                object
# engine_fuel_type     object
# transmission_type    object
# driven_wheels        object
# market_category      object
# vehicle_size         object
# vehicle_style        object
# dtype: object

# %%
# To get access index
df.dtypes[df.dtypes == 'object'].index
# Out:
# Index(['make', 'model', 'engine_fuel_type', 'transmission_type',
#        'driven_wheels', 'market_category', 'vehicle_size', 'vehicle_style'],
#       dtype='object')

# %%
# convert it to python list
list(df.dtypes[df.dtypes == 'object'].index)
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
# let's call it strings so this is a python list that contains all the string names
strings = list(df.dtypes[df.dtypes == 'object'].index)
strings
# Out:
# ['make',
#  'model',
#  'engine_fuel_type',
#  'transmission_type',
#  'driven_wheels',
#  'market_category',
#  'vehicle_size',
#  'vehicle_style']

# %%
# for column one of those lowercase replace spaces with underscores and write it back to the data frame
for col in strings:
    df[col] = df[col].str.lower().str.replace(' ', '_')

# %%
df.head()
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# 2               6.0            manual  rear_wheel_drive              2.0
# 3               6.0            manual  rear_wheel_drive              2.0
# 4               6.0            manual  rear_wheel_drive              2.0
#
#                          market_category vehicle_size vehicle_style  \
# ...

# %%
# some of these object column are strings, float64 are numbers
df.dtypes
# Out:
# make                  object
# model                 object
# year                   int64
# engine_fuel_type      object
# engine_hp            float64
# engine_cylinders     float64
# transmission_type     object
# driven_wheels         object
# number_of_doors      float64
# market_category       object
# vehicle_size          object
# vehicle_style         object
# highway_mpg            int64
# city_mpg               int64
# popularity             int64
# msrp                   int64
# dtype: object

# %% [markdown]
# ## 2.3 Exploratory data analysis

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)      335.0
# 1          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 2          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 3          bmw    1_series  2011     premium_unleaded_(required)      230.0
# 4          bmw    1_series  2011     premium_unleaded_(required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11910    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11911    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11912    acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11913  lincoln      zephyr  2006                regular_unleaded      221.0
#
# ...

# %%
df.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity', 'msrp'],
#       dtype='object')

# %%
# iterate over them 
for col in df.columns:
    print(col)
    print(df[col].unique()[:5])
    print(df[col].nunique())
    print()
# Out:
# make
# ['bmw' 'audi' 'fiat' 'mercedes-benz' 'chrysler']
# 48
#
# model
# ['1_series_m' '1_series' '100' '124_spider' '190-class']
# 914
#
# year
# [2011 2012 2013 1992 1993]
# 28
#
# engine_fuel_type
# ['premium_unleaded_(required)' 'regular_unleaded'
#  'premium_unleaded_(recommended)' 'flex-fuel_(unleaded/e85)' 'diesel']
# 10
#
# engine_hp
# [335. 300. 230. 320. 172.]
# 356
#
# engine_cylinders
# [ 6.  4.  5.  8. 12.]
# 9
#
# transmission_type
# ['manual' 'automatic' 'automated_manual' 'direct_drive' 'unknown']
# 5
#
# driven_wheels
# ['rear_wheel_drive' 'front_wheel_drive' 'all_wheel_drive'
#  'four_wheel_drive']
# 4
#
# number_of_doors
# [ 2.  4.  3. nan]
# 3
#
# market_category
# ['factory_tuner,luxury,high-performance' 'luxury,performance'
#  'luxury,high-performance' 'luxury' 'performance']
# 71
#
# vehicle_size
# ['compact' 'midsize' 'large']
# 3
#
# vehicle_style
# ['coupe' 'convertible' 'sedan' 'wagon' '4dr_hatchback']
# 16
#
# highway_mpg
# [26 28 27 25 24]
# 59
#
# ...

# %% [markdown]
# ## Visualize the dataset

# %%
# look at price column 
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)      335.0
# 1          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 2          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 3          bmw    1_series  2011     premium_unleaded_(required)      230.0
# 4          bmw    1_series  2011     premium_unleaded_(required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11910    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11911    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11912    acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11913  lincoln      zephyr  2006                regular_unleaded      221.0
#
# ...

# %% [markdown]
# Distribution of price

# %%
# for plotting we will use two libraries matplotlib is more like low level, seaborn library on top of it
import matplotlib.pyplot as plt
import seaborn as sns

# all these plots can be displayed in a notebook
# %matplotlib inline

# %%
# look now the distribution of prices to see how many different prices
# bins is how many bars
# left bars lot of prices that are pretty cheap
# on bar right side very few cars that are super expensive so there is just one car that costs two millions
# maybe one car that costs two million there is maybe one car that costs 1.5 millions maybe there are a few cars that cost 1 million.
# so there are so many of them right
sns.histplot(df.msrp, bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
# it's easier to actually see visually so most of the cars
# strange peak of cars that cost one thousand probably this is the minimal price that is possible to put on platform
sns.histplot(df.msrp[df.msrp < 100000], bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %%
# get rid of this long tail, so apply the logarithmic distribution
# for large values the the value of the logarithm is not that large 
# from 10 to 1000 but the increase between the logarithm of them is not that high
#np.log([0, 1, 10, 1000, 100000])
np.log([1, 10, 1000, 100000])
# Out:
# array([ 0.        ,  2.30258509,  6.90775528, 11.51292546])

# %%
# To add one to all 
np.log([0 + 1, 1+ 1, 10 + 1, 1000 + 1, 100000])
# Out:
# array([ 0.        ,  0.69314718,  2.39789527,  6.90875478, 11.51292546])

# %%
# don't want to add this plus one every time manually, so there is actually a function in numpy that can help us
# one piece stands for plus one, so it adds one to all the values and then it takes logarithm 
np.log1p([0, 1, 10, 1000, 100000])
# Out:
# array([ 0.        ,  0.69314718,  2.39789527,  6.90875478, 11.51293546])

# %%
price_logs = np.log1p(df.msrp)
price_logs
# Out:
# 0        10.739349
# 1        10.612779
# 2        10.500977
# 3        10.290483
# 4        10.448744
#            ...
# 11909    10.739024
# 11910    10.945018
# 11911    10.832122
# 11912    10.838031
# 11913    10.274913
# Name: msrp, Length: 11914, dtype: float64

# %%
# all these large prices they kind of collapse into this right side area
# all the prices like all the cars for usual consumers they're still concentrated around
# resembles a bit this bell curve shape called normal distribution
sns.histplot(price_logs, bins=50)
# Out:
# <Axes: xlabel='msrp', ylabel='Count'>

# %% [markdown]
# ## Missing values

# %%
df
# Out:
#           make       model  year                engine_fuel_type  engine_hp  \
# 0          bmw  1_series_m  2011     premium_unleaded_(required)      335.0
# 1          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 2          bmw    1_series  2011     premium_unleaded_(required)      300.0
# 3          bmw    1_series  2011     premium_unleaded_(required)      230.0
# 4          bmw    1_series  2011     premium_unleaded_(required)      230.0
# ...        ...         ...   ...                             ...        ...
# 11909    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11910    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11911    acura         zdx  2012     premium_unleaded_(required)      300.0
# 11912    acura         zdx  2013  premium_unleaded_(recommended)      300.0
# 11913  lincoln      zephyr  2006                regular_unleaded      221.0
#
# ...

# %%
df.isnull()
# Out:
#         make  model   year  engine_fuel_type  engine_hp  engine_cylinders  \
# 0      False  False  False             False      False             False
# 1      False  False  False             False      False             False
# 2      False  False  False             False      False             False
# 3      False  False  False             False      False             False
# 4      False  False  False             False      False             False
# ...      ...    ...    ...               ...        ...               ...
# 11909  False  False  False             False      False             False
# 11910  False  False  False             False      False             False
# 11911  False  False  False             False      False             False
# 11912  False  False  False             False      False             False
# 11913  False  False  False             False      False             False
#
#        transmission_type  driven_wheels  number_of_doors  market_category  \
# ...

# %%
df.isnull().sum()
# Out:
# make                    0
# model                   0
# year                    0
# engine_fuel_type        3
# engine_hp              69
# engine_cylinders       30
# transmission_type       0
# driven_wheels           0
# number_of_doors         6
# market_category      3742
# vehicle_size            0
# vehicle_style           0
# highway_mpg             0
# city_mpg                0
# popularity              0
# msrp                    0
# dtype: int64

# %% [markdown]
# ## 2.4 Setting up the validation framework

# %% [markdown]
# Let's draw it

# %%
# calculate how many 20 actually is
len(df)
# Out:
# 11914

# %%
# 20 of that is
len(df) * 0.2
# Out:
# 2382.8

# %%
# number that is integer round it
int(len(df) * 0.2)
# Out:
# 2382

# %%
# n variable will be the length of our data frame
n = len(df)

#  size of validation data set will be 20 of n 
n_val = int(n * 0.2)
# size of our test data set
n_test = int(n * 0.2)
#  train will be the size of our train data set so we can write here 0.6
#n_train = int(n * 0.6)
n_train = n - n_val - n_test

# %%
# so now let's check and test
# n here the number of records in our data frame is actually bigger than the size of this n_test
n, n_val + n_test + n_train
# Out:
# (11914, 11914)

# %%
# size which dataset for training
n_val, n_test, n_train
# Out:
# (2382, 2382, 7150)

# %%
n
# Out:
# 11914

# %%
# take a part of the data frame out of this size, we can use this i lock thing
# give it a list and it would return a data frame a subset of the data frame
# possible to use a range range so let's say if we want to get 10 first records 

#df.iloc[:10]
#df.iloc[10:20]
#df.iloc[11910:]
df.iloc[:n_val]



#df.iloc[[10, 0, 3, 5]]
# Out:
#          make       model  year             engine_fuel_type  engine_hp  \
# 0         bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1         bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2         bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3         bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4         bmw    1_series  2011  premium_unleaded_(required)      230.0
# ...       ...         ...   ...                          ...        ...
# 2377  porsche     cayenne  2016  premium_unleaded_(required)      570.0
# 2378  porsche     cayenne  2016                       diesel      240.0
# 2379  porsche     cayenne  2017  premium_unleaded_(required)      520.0
# 2380  porsche     cayenne  2017  premium_unleaded_(required)      300.0
# 2381  porsche     cayenne  2017  premium_unleaded_(required)      440.0
#
#       engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# ...

# %%
#df_val = df.iloc[:n_val]
#df_test = df.iloc[n_val:n_val+n_test]
#df_train = df.iloc[n_val+n_train:]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
df_train = df.iloc[n_train:]
df_val = df.iloc[n_train:n_train+n_val]
df_test = df.iloc[n_train+n_val:]

# %%
idx = np.arange(n)

# %%
df.iloc[idx[:10]]
# Out:
#   make       model  year             engine_fuel_type  engine_hp  \
# 0  bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2  bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4  bmw    1_series  2011  premium_unleaded_(required)      230.0
# 5  bmw    1_series  2012  premium_unleaded_(required)      230.0
# 6  bmw    1_series  2012  premium_unleaded_(required)      300.0
# 7  bmw    1_series  2012  premium_unleaded_(required)      300.0
# 8  bmw    1_series  2012  premium_unleaded_(required)      230.0
# 9  bmw    1_series  2013  premium_unleaded_(required)      230.0
#
#    engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# 0               6.0            manual  rear_wheel_drive              2.0
# 1               6.0            manual  rear_wheel_drive              2.0
# ...

# %%
df_train
# Out:
#           make      model  year                engine_fuel_type  engine_hp  \
# 7150   lincoln  navigator  2015                regular_unleaded      365.0
# 7151   lincoln  navigator  2016                regular_unleaded      380.0
# 7152   lincoln  navigator  2016                regular_unleaded      380.0
# 7153   lincoln  navigator  2016                regular_unleaded      380.0
# 7154   lincoln  navigator  2016                regular_unleaded      380.0
# ...        ...        ...   ...                             ...        ...
# 11909    acura        zdx  2012     premium_unleaded_(required)      300.0
# 11910    acura        zdx  2012     premium_unleaded_(required)      300.0
# 11911    acura        zdx  2012     premium_unleaded_(required)      300.0
# 11912    acura        zdx  2013  premium_unleaded_(recommended)      300.0
# 11913  lincoln     zephyr  2006                regular_unleaded      221.0
#
# ...

# %%
# in our validation data set now we have all the bmw, and we don't have bmws in train, 
# we see that there is some order in this uh in this data set, so we need to shuffle these records 
# make sure that there are bmws in all three data sets 
df_val
# Out:
#          make       model  year             engine_fuel_type  engine_hp  \
# 0         bmw  1_series_m  2011  premium_unleaded_(required)      335.0
# 1         bmw    1_series  2011  premium_unleaded_(required)      300.0
# 2         bmw    1_series  2011  premium_unleaded_(required)      300.0
# 3         bmw    1_series  2011  premium_unleaded_(required)      230.0
# 4         bmw    1_series  2011  premium_unleaded_(required)      230.0
# ...       ...         ...   ...                          ...        ...
# 2377  porsche     cayenne  2016  premium_unleaded_(required)      570.0
# 2378  porsche     cayenne  2016                       diesel      240.0
# 2379  porsche     cayenne  2017  premium_unleaded_(required)      520.0
# 2380  porsche     cayenne  2017  premium_unleaded_(required)      300.0
# 2381  porsche     cayenne  2017  premium_unleaded_(required)      440.0
#
#       engine_cylinders transmission_type     driven_wheels  number_of_doors  \
# ...

# %%
# generate a sequence of numbers from one to ns1 n minus one for that we use a function from numpy called arrange
idx = np.arange(n)
idx
# Out:
# array([    0,     1,     2, ..., 11911, 11912, 11913])

# %%
# shuffle it so for that there is a function in random called shuffle
np.random.seed(2)

np.random.shuffle(idx)
idx
# Out:
# array([2735, 6720, 5878, ..., 6637, 2575, 7336])

# %%
df.iloc[idx[:10]]
# Out:
#              make        model  year                engine_fuel_type  \
# 3274     cadillac          cts  2016  premium_unleaded_(recommended)
# 9781    chevrolet        sonic  2016                regular_unleaded
# 8078        dodge      ram_150  1993                regular_unleaded
# 8802          gmc         s-15  1990                regular_unleaded
# 7166      lincoln    navigator  2017                regular_unleaded
# 5460   volkswagen         golf  2016                regular_unleaded
# 4500         ford        f-150  2015        flex-fuel_(unleaded/e85)
# 6388       nissan         leaf  2015                        electric
# 8327   land_rover  range_rover  2016  premium_unleaded_(recommended)
# 11690      suzuki          xl7  2007                regular_unleaded
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# 3274       268.0               4.0         automatic    all_wheel_drive
# ...

# %%
# if we take first 60 of that we can use this for our trained data set 
df_train = df.iloc[idx[:n_train]]
df_val = df.iloc[idx[n_train:n_train+n_val]]
df_test = df.iloc[idx[n_train+n_val:]]

# %%
df_train.head()
# Out:
#              make    model  year          engine_fuel_type  engine_hp  \
# 2735    chevrolet   cobalt  2008          regular_unleaded      148.0
# 6720       toyota   matrix  2012          regular_unleaded      132.0
# 5878       subaru  impreza  2016          regular_unleaded      148.0
# 11190  volkswagen  vanagon  1991          regular_unleaded       90.0
# 4554         ford    f-150  2017  flex-fuel_(unleaded/e85)      385.0
#
#        engine_cylinders transmission_type      driven_wheels  number_of_doors  \
# 2735                4.0            manual  front_wheel_drive              2.0
# 6720                4.0         automatic  front_wheel_drive              4.0
# 5878                4.0         automatic    all_wheel_drive              4.0
# 11190               4.0            manual   rear_wheel_drive              3.0
# 4554                8.0         automatic   four_wheel_drive              4.0
#
# ...

# %%
# check the length of data sets
len(df_train), len(df_val), len(df_test)
# Out:
# (7150, 2382, 2382)

# %%
df_train
# Out:
#               make        model  year                engine_fuel_type  \
# 2735     chevrolet       cobalt  2008                regular_unleaded
# 6720        toyota       matrix  2012                regular_unleaded
# 5878        subaru      impreza  2016                regular_unleaded
# 11190   volkswagen      vanagon  1991                regular_unleaded
# 4554          ford        f-150  2017        flex-fuel_(unleaded/e85)
# ...            ...          ...   ...                             ...
# 434            bmw     4_series  2015     premium_unleaded_(required)
# 1902    volkswagen       beetle  2015  premium_unleaded_(recommended)
# 9334           gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)
# 5284   rolls-royce        ghost  2014     premium_unleaded_(required)
# 2420    volkswagen           cc  2017  premium_unleaded_(recommended)
#
#        engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
df_train.reset_index()
# Out:
#       index         make        model  year                engine_fuel_type  \
# 0      2735    chevrolet       cobalt  2008                regular_unleaded
# 1      6720       toyota       matrix  2012                regular_unleaded
# 2      5878       subaru      impreza  2016                regular_unleaded
# 3     11190   volkswagen      vanagon  1991                regular_unleaded
# 4      4554         ford        f-150  2017        flex-fuel_(unleaded/e85)
# ...     ...          ...          ...   ...                             ...
# 7145    434          bmw     4_series  2015     premium_unleaded_(required)
# 7146   1902   volkswagen       beetle  2015  premium_unleaded_(recommended)
# 7147   9334          gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)
# 7148   5284  rolls-royce        ghost  2014     premium_unleaded_(required)
# 7149   2420   volkswagen           cc  2017  premium_unleaded_(recommended)
#
# ...

# %%
# we don't need this index column that's why we drop it and we basically reassign it back to data frame 
df_train = df_train.reset_index(drop=True)
df_val = df_val.reset_index(drop=True)
df_test = df_test.reset_index(drop=True)

# %%
#df_train.msrp
np.log1p(df_train.msrp)
# Out:
# 0        9.575747
# 1        9.887663
# 2        9.893235
# 3        7.601402
# 4       10.937757
#           ...
# 7145    10.913287
# 7146    10.282472
# 7147    10.453803
# 7148    12.622481
# 7149    10.540620
# Name: msrp, Length: 7150, dtype: float64

# %%
# transformation with y
y_train = np.log1p(df_train.msrp.values)
y_val = np.log1p(df_val.msrp.values)
y_test = np.log1p(df_test.msrp.values)

# %%
# remove this msrp variable from our data frame
del df_train['msrp']
del df_val['msrp']
del df_test['msrp']

# %%
len(y_train)
# Out:
# 7150

# %% [markdown]
# ## 2.5 Linear regression

# %% [markdown]
# draw

# %%
df_train
# Out:
#              make        model  year                engine_fuel_type  \
# 0       chevrolet       cobalt  2008                regular_unleaded
# 1          toyota       matrix  2012                regular_unleaded
# 2          subaru      impreza  2016                regular_unleaded
# 3      volkswagen      vanagon  1991                regular_unleaded
# 4            ford        f-150  2017        flex-fuel_(unleaded/e85)
# ...           ...          ...   ...                             ...
# 7145          bmw     4_series  2015     premium_unleaded_(required)
# 7146   volkswagen       beetle  2015  premium_unleaded_(recommended)
# 7147          gmc  sierra_1500  2015        flex-fuel_(unleaded/e85)
# 7148  rolls-royce        ghost  2014     premium_unleaded_(required)
# 7149   volkswagen           cc  2017  premium_unleaded_(recommended)
#
#       engine_hp  engine_cylinders transmission_type      driven_wheels  \
# ...

# %%
# look at row number 10
df_train.iloc[10]
# Out:
# make                                 rolls-royce
# model                     phantom_drophead_coupe
# year                                        2015
# engine_fuel_type     premium_unleaded_(required)
# engine_hp                                  453.0
# engine_cylinders                            12.0
# transmission_type                      automatic
# driven_wheels                   rear_wheel_drive
# number_of_doors                              2.0
# market_category        exotic,luxury,performance
# vehicle_size                               large
# vehicle_style                        convertible
# highway_mpg                                   19
# city_mpg                                      11
# popularity                                    86
# Name: 10, dtype: object

# %% [markdown]
# so let's just take engine horsepower, city miles per gallon and popularity

# %%
# engine horsepowers, city_mpg and popularity is feature matrix
# [453, 11, 86]
xi = [453, 11, 86]

# %%
def g(xi):
    # do something
    return 10000

# %%
g(xi)
# Out:
# 10000

# %%
xi = [453, 11, 86]
# sum  w0 which is bias term
w0 = 7.17
# w which is a vector
w = [0.01, 0.04, 0.002]

# %% [markdown]
# ![image.png](attachment:image.png)  ![image-2.png](attachment:image-2.png)

# %%
# simple linear regression
def linear_regression(xi):
    n = len(xi)

    pred = w0

    for j in range(n):
        # feature vector multiply by corresponding weight goes to prediction 
        pred = pred + w[j] * xi[j]

    return pred

# %%
# bias term (7.17) multiply feature engine horsepower by its weight (453.0.01),
# next feature which is gallons per mile in the city with its weight (11.0.04)
# finally popularity which is 86 and then the weight for this popularity (86.002)
7.17 + 453.0.01 + 11.0.04 + 86.002 = 12.312
xi = [453, 11, 86]
# bias term 
w0 = 7.17
w = [0.01, 0.04, 0.002]

# %%
linear_regression(xi)
# Out:
# 12.312

# %%
np.expm1(12.312)
# Out:
# 222347.2221101062

# %%
np.log1p(222347.2221101062)
# Out:
# 12.312

# %% [markdown]
# ## 2.6 Linear regression vector form

# %%
# dot product
# create a function dot product vector vector multiplication
def dot(xi, w):
    n = len(xi)
    # result which is zero 
    res = 0.0
    
    # each element multiply them with each other
    for j in range(n):
        res = res + xi[j] * w[j]
    
    return res

# %%
def linear_regression(xi):
    return w0 + dot(xi, w)

# %%
#  new uh vector with weights
w_new = [w0] + w

# %%
# if you do plus on python list it creates a new list 
[1] + [1, 2, 3]
# Out:
# [1, 1, 2, 3]

# %%
# w new contains the bias term and then the rest of the features
w_new
# Out:
# [7.17, 0.01, 0.04, 0.002]

# %%
def linear_regression(xi):
    xi = [1] + xi
    return dot(xi, w_new)

# %%
linear_regression(xi)
# Out:
# 12.312

# %%
#xi = [458, 11, 86]
#w0 = 7.17
#w = [0.01, 0.04, 0.002]

# %%
# different observations
w0 = 7.17
w = [0.01, 0.04, 0.002]
w_new = [w0] + w

# %%
# add once 148 horsepowers then 24 miles per gallon and then it has popularity of 1385.
# multiple rows at the same time 
x1  = [1, 148, 24, 1385]
x2  = [1, 132, 25, 2031]
x10 = [1, 453, 11, 86]

# list of lists and put this into numpy it turns list of lists into a matrix
X = [x1, x2, x10]
X = np.array(X)
X
# Out:
# array([[   1,  148,   24, 1385],
#        [   1,  132,   25, 2031],
#        [   1,  453,   11,   86]])

# %%
X.dot(w_new)
# Out:
# array([12.38 , 13.552, 12.312])

# %%
# multiplication between matrix and vector

def linear_regression(X):
    return X.dot(w_new)

# %%
linear_regression(X)
# Out:
# array([12.38 , 13.552, 12.312])

# %% [markdown]
# ## 2.7 Training a linear regression model

# %%
# train linear regression the input x and the y
def train_linear_regression(X, y):
    pass

# %%
X
# Out:
# array([[1.000e+00, 1.480e+02, 2.400e+01, 1.385e+03],
#        [1.000e+00, 1.320e+02, 2.500e+01, 2.031e+03],
#        [1.000e+00, 4.530e+02, 1.100e+01, 8.600e+01],
#        [1.000e+00, 1.580e+02, 2.400e+01, 1.850e+02],
#        [1.000e+00, 1.720e+02, 2.500e+01, 2.010e+02],
#        [1.000e+00, 4.130e+02, 1.100e+01, 8.600e+01],
#        [1.000e+00, 3.800e+01, 5.400e+01, 1.850e+02],
#        [1.000e+00, 1.420e+02, 2.500e+01, 4.310e+02],
#        [1.000e+00, 4.530e+02, 3.100e+01, 8.600e+01]])

# %%
# creating a list of lists
X = [
    [148, 24, 1385],
    [132, 25, 2031],
    [453, 11, 86],
    [158, 24, 185],
    [172, 25, 201],
    [413, 11, 86],
    [38,  54, 185],
    [142, 25, 431],
    [453, 31, 86],
]

X = np.array(X)
X
# Out:
# array([[ 148,   24, 1385],
#        [ 132,   25, 2031],
#        [ 453,   11,   86],
#        [ 158,   24,  185],
#        [ 172,   25,  201],
#        [ 413,   11,   86],
#        [  38,   54,  185],
#        [ 142,   25,  431],
#        [ 453,   31,   86]])

# %%
# include the bias term
#np.ones(9)
ones = np.ones(X.shape[0])
ones
# Out:
# array([1., 1., 1., 1., 1., 1., 1., 1., 1.])

# %%
# function in numpy called column stack take two vectors and stack them together as calls
#list(np.column_stack([ones, X]))
X = np.column_stack([ones, X])

# %%
y = [10000, 20000, 15000, 20050, 10000, 20000, 15000, 25000, 12000]

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# the grammatics
XTX = X.T.dot(X)

# %%
# to find inverse
XTX_inv = np.linalg.inv(XTX)

# %%
#XTX.dot(XTX_inv).round(1)

# %%
w_full = XTX_inv.dot(X.T).dot(y)
w_full
# Out:
# array([ 2.58447541e+04, -1.60890647e+01, -1.99472549e+02, -1.22802883e+00])

# %%
# decompose it v0 is the first one
w0 = w_full[0]
# w take the rest one and everything after one
w = w_full[1:]

# %%
# coefficients for our linear regression
w0, w
# Out:
# (25844.75405576687, array([ -16.08906468, -199.47254894,   -1.22802883]))

# %%
def train_linear_regression(X, y):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)
    
    return w_full[0], w_full[1:]

# %%
train_linear_regression(X, y)
# Out:
# ---------------------------------------------------------------------------
# LinAlgError                               Traceback (most recent call last)
# Cell In[199], line 1
# ----> 1 train_linear_regression(X, y)
#
# Cell In[198], line 6, in train_linear_regression(X, y)
#       3 X = np.column_stack([ones, X])
#       5 XTX = X.T.dot(X)
# ----> 6 XTX_inv = np.linalg.inv(XTX)
#       7 w_full = XTX_inv.dot(X.T).dot(y)
#       9 return w_full[0], w_full[1:]
#
# File c:\Users\Daiyaan\miniconda3\Lib\site-packages\numpy\linalg\linalg.py:561, in inv(a)
#     559 signature = 'D->D' if isComplexType(t) else 'd->d'
#     560 extobj = get_linalg_error_extobj(_raise_linalgerror_singular)
# --> 561 ainv = _umath_linalg.inv(a, signature=signature, extobj=extobj)
#     562 return wrap(ainv.astype(result_t, copy=False))
#
# File c:\Users\Daiyaan\miniconda3\Lib\site-packages\numpy\linalg\linalg.py:112, in _raise_linalgerror_singular(err, flag)
# ...

# %% [markdown]
# ## 2.8 Car price baseline model

# %%
df_train.columns
# Out:
# Index(['make', 'model', 'year', 'engine_fuel_type', 'engine_hp',
#        'engine_cylinders', 'transmission_type', 'driven_wheels',
#        'number_of_doors', 'market_category', 'vehicle_size', 'vehicle_style',
#        'highway_mpg', 'city_mpg', 'popularity'],
#       dtype='object')

# %%
base = ['engine_hp', 'engine_cylinders', 'highway_mpg',
        'city_mpg', 'popularity']

X_train = df_train[base].fillna(0).values

w0, w = train_linear_regression(X_train, y_train)

y_pred = w0 + X_train.dot(w)

# %%
w0
# Out:
# 7.9272573880700605

# %%
w
# Out:
# array([ 9.70589522e-03, -1.59103494e-01,  1.43792133e-02,  1.49441072e-02,
#        -9.06908672e-06])

# %%
sns.histplot(y_pred, color='red', alpha=0.5, bins=50)
sns.histplot(y_train, color='blue', alpha=0.5, bins=50)
# Out:
# <AxesSubplot:ylabel='Count'>

# %% [markdown]
# ## 2.9 RMSE

# %%
def rmse(y, y_pred):
    se = (y - y_pred) ** 2
    mse = se.mean()
    return np.sqrt(mse)

# %%
rmse(y_train, y_pred)
# Out:
# 0.7554192603920132

# %% [markdown]
# ## 2.10 Validating the model

# %%
def prepare_X(df):
    df_num = df[base]
    df_num = df_num.fillna(0)
    X = df_num.values
    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# 0.7616530991301577

# %% [markdown]
# ## 2.11 Simple feature engineering

# %%
def prepare_X(df):
    df = df.copy()
    
    df['age'] = 2017 - df['year']
    features = base + ['age']
    
    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# 0.5172055461058291

# %%
sns.histplot(y_pred, label='prediction', color='red', alpha=0.5, bins=50)
sns.histplot(y_val, label='target', color='blue',  alpha=0.5, bins=50)
plt.legend()

# %% [markdown]
# ## 2.12 Categorical variables

# %%
categorical_columns = [
    'make', 'model', 'engine_fuel_type', 'driven_wheels', 'market_category',
    'vehicle_size', 'vehicle_style']

categorical = {}

for c in categorical_columns:
    categorical[c] = list(df_train[c].value_counts().head().index)

# %%
def prepare_X(df):
    df = df.copy()
    
    df['age'] = 2017 - df['year']
    features = base + ['age']

    for v in [2, 3, 4]:
        df['num_doors_%d' % v] = (df.number_of_doors == v).astype(int)
        features.append('num_doors_%d' % v)

    for name, values in categorical.items():
        for value in values:
            df['%s_%s' % (name, value)] = (df[name] == value).astype(int)
            features.append('%s_%s' % (name, value))

    df_num = df[features]
    df_num = df_num.fillna(0)
    X = df_num.values

    return X

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression(X_train, y_train)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# 266.5994263627081

# %%
w0, w
# Out:
# (3066759258862621.0,
#  array([-7.90863204e-01,  1.80621909e+02,  1.97903973e+01,  1.46968041e+01,
#         -3.39713455e-04,  7.74924546e+00,  9.76297867e+03,  9.83480038e+03,
#          9.77003629e+03, -2.36936868e+01, -6.98582110e+00,  7.93435108e+01,
#         -7.33167695e+01, -6.60897799e+00, -1.00310530e+01,  7.79383982e+01,
#         -4.19367134e+01, -6.14213575e+01,  2.12412304e+02,  1.02166851e+03,
#          9.08719092e+02,  9.84633740e+02,  1.06771237e+03,  7.00547494e+02,
#         -3.06675926e+15, -3.06675926e+15, -3.06675926e+15, -3.06675926e+15,
#          2.52356626e+00,  3.40712703e+00, -1.27416249e+01,  1.22844560e+01,
#         -1.51620939e+01,  3.09315910e+02,  2.88692636e+02,  2.78158171e+02,
#         -1.44115660e-01, -2.62579827e-02,  1.75913981e-01,  3.65037816e-01,
#         -2.90235596e-01]))

# %% [markdown]
# ## 2.13 Regularization

# %%
X = [
    [4, 4, 4],
    [3, 5, 5],
    [5, 1, 1],
    [5, 4, 4],
    [7, 5, 5],
    [4, 5, 5.00000001],
]

X = np.array(X)
X
# Out:
# array([[4.        , 4.        , 4.        ],
#        [3.        , 5.        , 5.        ],
#        [5.        , 1.        , 1.        ],
#        [5.        , 4.        , 4.        ],
#        [7.        , 5.        , 5.        ],
#        [4.        , 5.        , 5.00000001]])

# %%
y= [1, 2, 3, 1, 2, 3]

# %%
XTX = X.T.dot(X)
XTX
# Out:
# array([[140.        , 111.        , 111.00000004],
#        [111.        , 108.        , 108.00000005],
#        [111.00000004, 108.00000005, 108.0000001 ]])

# %%
XTX_inv = np.linalg.inv(XTX)

# %%
XTX_inv
# Out:
# array([[ 3.85321698e-02,  1.20696663e+05, -1.20696696e+05],
#        [ 1.20696640e+05, -2.74658839e+14,  2.74658839e+14],
#        [-1.20696680e+05,  2.74658839e+14, -2.74658839e+14]])

# %%
XTX_inv.dot(X.T).dot(y)
# Out:
# array([ 6.24269892e-01,  3.44329390e+06, -3.44329299e+06])

# %%
XTX = [
    [1, 2, 2],
    [2, 1, 1.0000001],
    [2, 1.0000001, 1]
]

XTX = np.array(XTX)

# %%
np.linalg.inv(XTX)
# Out:
# array([[-3.33333356e-01,  3.33333339e-01,  3.33333339e-01],
#        [ 3.33333339e-01, -5.00000008e+06,  4.99999991e+06],
#        [ 3.33333339e-01,  4.99999991e+06, -5.00000008e+06]])

# %%
XTX = XTX + 0.01 * np.eye(3)

# %%
np.linalg.inv(XTX)
# Out:
# array([[ -0.33668908,   0.33501399,   0.33501399],
#        [  0.33501399,  49.91590897, -50.08509104],
#        [  0.33501399, -50.08509104,  49.91590897]])

# %%
def train_linear_regression_reg(X, y, r=0.001):
    ones = np.ones(X.shape[0])
    X = np.column_stack([ones, X])

    XTX = X.T.dot(X)
    XTX = XTX + r * np.eye(XTX.shape[0])

    XTX_inv = np.linalg.inv(XTX)
    w_full = XTX_inv.dot(X.T).dot(y)
    
    return w_full[0], w_full[1:]

# %%
X_train = prepare_X(df_train)
w0, w = train_linear_regression_reg(X_train, y_train, r=0.01)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
rmse(y_val, y_pred)
# Out:
# 0.4608208286209523

# %% [markdown]
# ## 2.14 Tuning the model

# %%
for r in [0.0, 0.00001, 0.0001, 0.001, 0.1, 1, 10]:
    X_train = prepare_X(df_train)
    w0, w = train_linear_regression_reg(X_train, y_train, r=r)

    X_val = prepare_X(df_val)
    y_pred = w0 + X_val.dot(w)
    score = rmse(y_val, y_pred)
    
    print(r, w0, score)
# Out:
# 0.0 3066759258862621.0 266.5994263627081
# 1e-05 6.6398149018651305 0.46081532123609276
# 0.0001 7.12965014007955 0.4608153659783837
# 0.001 7.13085491393288 0.46081585838957173
# 0.1 7.0002324128629025 0.4608736549134577
# 1 6.250747846974607 0.46158128382779856
# 10 4.7295125856710305 0.472609877266903

# %%
r = 0.001
X_train = prepare_X(df_train)
w0, w = train_linear_regression_reg(X_train, y_train, r=r)

X_val = prepare_X(df_val)
y_pred = w0 + X_val.dot(w)
score = rmse(y_val, y_pred)
score
# Out:
# 0.46081585838957173

# %% [markdown]
# ## 2.15 Using the model

# %%
df_full_train = pd.concat([df_train, df_val])

# %%
df_full_train = df_full_train.reset_index(drop=True)

# %%
X_full_train = prepare_X(df_full_train)

# %%
X_full_train
# Out:
# array([[148.,   4.,  33., ...,   1.,   0.,   0.],
#        [132.,   4.,  32., ...,   0.,   0.,   1.],
#        [148.,   4.,  37., ...,   0.,   0.,   1.],
#        ...,
#        [332.,   8.,  23., ...,   0.,   0.,   0.],
#        [148.,   4.,  34., ...,   0.,   0.,   0.],
#        [290.,   6.,  25., ...,   0.,   0.,   0.]])

# %%
y_full_train = np.concatenate([y_train, y_val])

# %%
w0, w = train_linear_regression_reg(X_full_train, y_full_train, r=0.001)

# %%
X_test = prepare_X(df_test)
y_pred = w0 + X_test.dot(w)
score = rmse(y_test, y_pred)
score
# Out:
# 0.4600753970266562

# %%
car = df_test.iloc[20].to_dict()
car
# Out:
# {'make': 'toyota',
#  'model': 'sienna',
#  'year': 2015,
#  'engine_fuel_type': 'regular_unleaded',
#  'engine_hp': 266.0,
#  'engine_cylinders': 6.0,
#  'transmission_type': 'automatic',
#  'driven_wheels': 'front_wheel_drive',
#  'number_of_doors': 4.0,
#  'market_category': nan,
#  'vehicle_size': 'large',
#  'vehicle_style': 'passenger_minivan',
#  'highway_mpg': 25,
#  'city_mpg': 18,
#  'popularity': 2031}

# %%
df_small = pd.DataFrame([car])
df_small
# Out:
#      make   model  year  engine_fuel_type  engine_hp  engine_cylinders  \
# 0  toyota  sienna  2015  regular_unleaded      266.0               6.0
#
#   transmission_type      driven_wheels  number_of_doors  market_category  \
# 0         automatic  front_wheel_drive              4.0              NaN
#
#   vehicle_size      vehicle_style  highway_mpg  city_mpg  popularity
# 0        large  passenger_minivan           25        18        2031

# %%
X_small = prepare_X(df_small)

# %%
y_pred = w0 + X_small.dot(w)
y_pred = y_pred[0]
y_pred
# Out:
# 10.63249250912739

# %%
np.expm1(y_pred)
# Out:
# 41459.336786653585

# %%
np.expm1(y_test[20])
# Out:
# 35000.00000000001

# %% [markdown]
# ## 2.16 Next steps

# %% [markdown]
# * We included only 5 top features. What happens if we include 10?
#
# Other projects
#
# * Predict the price of a house - e.g. boston dataset
# * https://archive.ics.uci.edu/ml/datasets.php?task=reg
# * https://archive.ics.uci.edu/ml/datasets/Student+Performance

# %% [markdown]
# ## 2.17 Summary
#
# * EDA - looking at data, finding missing values
# * Target variable distribution - long tail => bell shaped curve
# * Validation framework: train/val/test split (helped us detect problems)
# * Normal equation - not magic, but math
# * Implemented it with numpy
# * RMSE to validate our model
# * Feature engineering: age, categorical features
# * Regularization to fight numerical instability
